# %% [markdown]
# Why Pandas? <br>
# -> Importing data sets<br>
# -> Data Cleansing<br>
# -> Reshaping and pivoting of data sets<br>
# -> Size mutability<br>
# -> Efficient manipulation and extraction<br>
# -> Statistical Analysis

# %% [markdown]
# There are 2 primary data structures in Pandas: DataFrames and Series.<br>
# Data structures are the collection of data types that provide the best way to organize the items(values) in terms of memory usage.

# %% [markdown]
# Series is one-dimensional labeled homogeneous array, size immutable. Values will have an index value.<br>
# It is a series of integers or strings, if you add any string value in the array of integers, all the integers will be changed to strings. The data type of this series would be object. If the array will consist only integers, the data type would be int. Since a series is immutable, if you try to delete any row, it will be removed but the original array will not be manipulated, instead you will be returned a new series.<br>
# DataFrame is a two dimensional labeled size mutable tabular data structure with potentially heterogeneously types columns. Since it is two dimensional, so we can have multiple columns and multiple rows

# %%
import pandas as pd

# %%
s = pd.Series([10, 20, 30, 40])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.values
# Out:
# array([10, 20, 30, 40])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
print(s.name)
# Out:
# None

# %%
s.name = "numbers"
s.name
# Out:
# 'numbers'

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# Name: numbers, dtype: int64

# %%
# Indexing
print(s[0])
print(s[0:2]) # start(included):stop(excluded):step(values to jump)
# Out:
# 10
# 0    10
# 1    20
# Name: numbers, dtype: int64

# %%
# iloc -> location based indexing
print(s.iloc[1])
print(s.iloc[[1, 3]])
# Out:
# 20
# 1    20
# 3    40
# Name: numbers, dtype: int64

# %%
s.name = "calories"
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# Name: calories, dtype: int64

# %%
index = ["banana", "mango", "strawberry", "kiwi"]
s.index = index
s
# Out:
# banana        10
# mango         20
# strawberry    30
# kiwi          40
# dtype: int64

# %%
s["kiwi"]
# Out:
# np.int64(40)

# %%
# We can't use these indexes in iloc since it is a location based indexing. We write indexes in iloc normally as we write for lists or arrays in numpy. But in case we dont remember the indexes, we can use loc function
# loc is label based indexing
print(s.loc['mango'])
print(s.loc[['mango', 'banana']])
# Out:
# 20
# mango     20
# banana    10
# dtype: int64

# %%
# In label based indexing, start and stop both values are included
s.loc['mango':'kiwi']
# Out:
# mango         20
# strawberry    30
# kiwi          40
# dtype: int64

# %%
fruit_proteins = { # proteins in grams
    "mango": 1.1,
    "kiwi" : 2.2,
    "strawberry":0.1,
    "blueberry":2.3,
    "apple":4.2,
    "banana":2.2,
    "orange":1.3,
    "litchi":2.0,
    "grapes":3.3,
    "pomegranate":2.1
}

# %%
s2 = pd.Series(fruit_proteins, name ="Fruit Proteins")
s2
# Out:
# mango          1.1
# kiwi           2.2
# strawberry     0.1
# blueberry      2.3
# apple          4.2
# banana         2.2
# orange         1.3
# litchi         2.0
# grapes         3.3
# pomegranate    2.1
# Name: Fruit Proteins, dtype: float64

# %%
# Conditional Selection
s2>1 # you get a mask series
# Out:
# mango           True
# kiwi            True
# strawberry     False
# blueberry       True
# apple           True
# banana          True
# orange          True
# litchi          True
# grapes          True
# pomegranate     True
# Name: Fruit Proteins, dtype: bool

# %%
s2[s2 > 1] # when you write mask series inside square brackets you get only those indexes which satisfy this condition and have a True boolean value
# Out:
# mango          1.1
# kiwi           2.2
# blueberry      2.3
# apple          4.2
# banana         2.2
# orange         1.3
# litchi         2.0
# grapes         3.3
# pomegranate    2.1
# Name: Fruit Proteins, dtype: float64

# %%
# Logical Operators - AND, OR, NOT
print((s2 > 2) & (s2 < 2.3))
print(s2[(s2 >= 2) & (s2 < 2.3)])

print((s2 > 3) | (s2 < 1.3))
print(s2[(s2 > 3) | (s2 < 1.3)])

print(~(s2 > 2))
print(s2[~(s2 > 2)])
# Out:
# mango          False
# kiwi            True
# strawberry     False
# blueberry      False
# apple          False
# banana          True
# orange         False
# litchi         False
# grapes         False
# pomegranate     True
# Name: Fruit Proteins, dtype: bool
# kiwi           2.2
# banana         2.2
# litchi         2.0
# pomegranate    2.1
# Name: Fruit Proteins, dtype: float64
# mango           True
# kiwi           False
# strawberry      True
# blueberry      False
# apple           True
# banana         False
# orange         False
# litchi         False
# grapes          True
# pomegranate    False
# Name: Fruit Proteins, dtype: bool
# mango         1.1
# strawberry    0.1
# apple         4.2
# grapes        3.3
# Name: Fruit Proteins, dtype: float64
# mango           True
# kiwi           False
# strawberry      True
# blueberry      False
# apple          False
# banana         False
# orange          True
# litchi          True
# grapes         False
# pomegranate    False
# Name: Fruit Proteins, dtype: bool
# mango         1.1
# strawberry    0.1
# orange        1.3
# litchi        2.0
# Name: Fruit Proteins, dtype: float64

# %%
# Modifying the Panda series
s2["mango"] = 2.8
s2
# Out:
# mango          2.8
# kiwi           2.2
# strawberry     0.1
# blueberry      2.3
# apple          4.2
# banana         2.2
# orange         1.3
# litchi         2.0
# grapes         3.3
# pomegranate    2.1
# Name: Fruit Proteins, dtype: float64

# %%
import numpy as np
ser = pd.Series(['a', np.nan, 1, np.nan, 2])
ser.notnull().sum()
# Out:
# np.int64(3)

# %%
# Data Frames
data = {
    "Name":["Alice", "Bob", "Eve", "Ali", "Jane"],
    "Age":[31, 78, 96, np.nan, 12],
    "Department":["IT", "Finance", "Production", "Supply Chain", "QAC"],
    "Salary":[12000, 90000, 3400, 8000, 34200]
}

data
# Out:
# {'Name': ['Alice', 'Bob', 'Eve', 'Ali', 'Jane'],
#  'Age': [31, 78, 96, nan, 12],
#  'Department': ['IT', 'Finance', 'Production', 'Supply Chain', 'QAC'],
#  'Salary': [12000, 90000, 3400, 8000, 34200]}

# %%
df = pd.DataFrame(data)
df
# Out:
#     Name   Age    Department  Salary
# 0  Alice  31.0            IT   12000
# 1    Bob  78.0       Finance   90000
# 2    Eve  96.0    Production    3400
# 3    Ali   NaN  Supply Chain    8000
# 4   Jane  12.0           QAC   34200

# %%
df.head(2)
# Out:
#     Name   Age Department  Salary
# 0  Alice  31.0         IT   12000
# 1    Bob  78.0    Finance   90000

# %%
df.tail(3)
# Out:
#    Name   Age    Department  Salary
# 2   Eve  96.0    Production    3400
# 3   Ali   NaN  Supply Chain    8000
# 4  Jane  12.0           QAC   34200

# %%
df.iloc[1:3, :2] # rows, columns
# Out:
#   Name   Age
# 1  Bob  78.0
# 2  Eve  96.0

# %%
df.loc[1:3]
# Out:
#   Name   Age    Department  Salary
# 1  Bob  78.0       Finance   90000
# 2  Eve  96.0    Production    3400
# 3  Ali   NaN  Supply Chain    8000

# %%
df.loc[1:3, ["Age", "Salary"]]
# Out:
#     Age  Salary
# 1  78.0   90000
# 2  96.0    3400
# 3   NaN    8000

# %%
df["Age"]
# Out:
# 0    31.0
# 1    78.0
# 2    96.0
# 3     NaN
# 4    12.0
# Name: Age, dtype: float64

# %%
df[["Age", "Name"]]
# Out:
#     Age   Name
# 0  31.0  Alice
# 1  78.0    Bob
# 2  96.0    Eve
# 3   NaN    Ali
# 4  12.0   Jane

# %%
# If column operation -> axis = 1
# If row operation -> axis = 0
new_df = df.drop("Age", axis = 1)

# %%
df
# Since inplace = False by default, to remove the Age column from dataframe we need to change inplace to True
# df.drop("Age", axis = 1, inplace=True)
# Out:
#     Name   Age    Department  Salary
# 0  Alice  31.0            IT   12000
# 1    Bob  78.0       Finance   90000
# 2    Eve  96.0    Production    3400
# 3    Ali   NaN  Supply Chain    8000
# 4   Jane  12.0           QAC   34200

# %%
df.shape # 5 samples
# Out:
# (5, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        5 non-null      object
#  1   Age         4 non-null      float64
#  2   Department  5 non-null      object
#  3   Salary      5 non-null      int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 292.0+ bytes

# %%
df.describe() # Statistical Analysis
# 25 % -> lower quartile
# The value below which there is 25% data
# 50 % -> median (middle point)
# The value below which there is 50% data
# 75 % -> upper quartile
# The value below which there is 75% data
# Out:
#              Age        Salary
# count   4.000000      5.000000
# mean   54.250000  29520.000000
# std    39.296946  35819.156886
# min    12.000000   3400.000000
# 25%    26.250000   8000.000000
# 50%    54.500000  12000.000000
# 75%    82.500000  34200.000000
# max    96.000000  90000.000000

# %%
# Broadcasting
# Columns are also called features
print(df["Salary"])
df["Salary"] = df["Salary"] + 5000 # Scalar has been broadcasted to match the shape or size of the particular column and then operation is being performed
df["Salary"]
# Out:
# 0    12000
# 1    90000
# 2     3400
# 3     8000
# 4    34200
# Name: Salary, dtype: int64
# 0    17000
# 1    95000
# 2     8400
# 3    13000
# 4    39200
# Name: Salary, dtype: int64

# %%
# Renaming a column
df.rename(columns = {"Department":"Dept"}, inplace = True)
df.rename(columns = {"Name":"Employee", "Salary":"Pay"}, inplace = True)
df
# Out:
#   Employee   Age          Dept    Pay
# 0    Alice  31.0            IT  17000
# 1      Bob  78.0       Finance  95000
# 2      Eve  96.0    Production   8400
# 3      Ali   NaN  Supply Chain  13000
# 4     Jane  12.0           QAC  39200

# %%
df.iloc[1, 3] = 17000
df["Dept"].unique()
# Out:
# array(['IT', 'Finance', 'Production', 'Supply Chain', 'QAC'], dtype=object)

# %%
df["Pay"].value_counts()
# Out:
# Pay
# 17000    2
# 8400     1
# 13000    1
# 39200    1
# Name: count, dtype: int64

# %%
df["Promoted Salary"] = df["Pay"] * 10 # Broadcasting rule
df
# Out:
#   Employee   Age          Dept    Pay  Promoted Salary
# 0    Alice  31.0            IT  17000           170000
# 1      Bob  78.0       Finance  17000           170000
# 2      Eve  96.0    Production   8400            84000
# 3      Ali   NaN  Supply Chain  13000           130000
# 4     Jane  12.0           QAC  39200           392000

# %%
df.iloc[2, 3] = np.nan

# Data Cleaning
df.isnull().sum()
# Out:
# Employee           0
# Age                1
# Dept               0
# Pay                1
# Promoted Salary    0
# dtype: int64

# %%
df.dropna(how="any") # any row that had any null value
# Out:
#   Employee   Age     Dept      Pay  Promoted Salary
# 0    Alice  31.0       IT  17000.0           170000
# 1      Bob  78.0  Finance  17000.0           170000
# 4     Jane  12.0      QAC  39200.0           392000

# %%
df # Since i didnot use inplace=True so the original dataframe remains unchanged
# Out:
#   Employee   Age          Dept      Pay  Promoted Salary
# 0    Alice  31.0            IT  17000.0           170000
# 1      Bob  78.0       Finance  17000.0           170000
# 2      Eve  96.0    Production      NaN            84000
# 3      Ali   NaN  Supply Chain  13000.0           130000
# 4     Jane  12.0           QAC  39200.0           392000

# %%
df.dropna(how="all") # if all values are null, then the row will be deleted
# Out:
#   Employee   Age          Dept      Pay  Promoted Salary
# 0    Alice  31.0            IT  17000.0           170000
# 1      Bob  78.0       Finance  17000.0           170000
# 2      Eve  96.0    Production      NaN            84000
# 3      Ali   NaN  Supply Chain  13000.0           130000
# 4     Jane  12.0           QAC  39200.0           392000

# %%
df["Age"].fillna(df["Age"].mean())
df["Pay"].fillna(df["Pay"].median())
# Out:
# 0    17000.0
# 1    17000.0
# 2    17000.0
# 3    13000.0
# 4    39200.0
# Name: Pay, dtype: float64

# %%
df["Pay"].fillna(method="ffill") # Forward fill
# Out:
# /tmp/ipython-input-1636759765.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["Pay"].fillna(method="ffill") # Forward fill
# 0    17000.0
# 1    17000.0
# 2    17000.0
# 3    13000.0
# 4    39200.0
# Name: Pay, dtype: float64

# %%
df["Pay"].fillna(method="bfill") # Backward Fill
# Out:
# /tmp/ipython-input-1449860753.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["Pay"].fillna(method="bfill") # Backward Fill
# 0    17000.0
# 1    17000.0
# 2    13000.0
# 3    13000.0
# 4    39200.0
# Name: Pay, dtype: float64

# %% [markdown]
# If there is null value above and we are using forward fill then the value still remains null, same case is for backward fill too.

# %%
df.iloc[0, 3] = np.nan
df.iloc[1, 3] = np.nan
df["Pay"].ffill()
df["Age"].bfill()
df
# Out:
#   Employee   Age          Dept      Pay  Promoted Salary
# 0    Alice  31.0            IT      NaN           170000
# 1      Bob  78.0       Finance      NaN           170000
# 2      Eve  96.0    Production      NaN            84000
# 3      Ali   NaN  Supply Chain  13000.0           130000
# 4     Jane  12.0           QAC  39200.0           392000

# %%
df["Employee"] = df["Employee"].replace("Bob", "Rose")
df
# Out:
#   Employee   Age          Dept      Pay  Promoted Salary
# 0    Alice  31.0            IT      NaN           170000
# 1     Rose  78.0       Finance      NaN           170000
# 2      Eve  96.0    Production      NaN            84000
# 3      Ali   NaN  Supply Chain  13000.0           130000
# 4     Jane  12.0           QAC  39200.0           392000

# %%
# Adding a new row
new_row = pd.DataFrame([{"Employee":"Alice", "Age":31.0, "Dept":"IT", "Pay":np.nan, "Promoted Salary":120000}])
df = pd.concat([df, new_row], ignore_index=True)
df
# Out:
#   Employee   Age          Dept      Pay  Promoted Salary
# 0    Alice  31.0            IT      NaN           170000
# 1     Rose  78.0       Finance      NaN           170000
# 2      Eve  96.0    Production      NaN            84000
# 3      Ali   NaN  Supply Chain  13000.0           130000
# 4     Jane  12.0           QAC  39200.0           392000
# 5    Alice  31.0            IT      NaN           120000

# %%
# Duplicates:

df[df.duplicated(keep="first")]
# Out:
# Empty DataFrame
# Columns: [Employee, Age, Dept, Pay, Promoted Salary]
# Index: []

# %%
df[df.duplicated(keep="last")]
# Out:
# Empty DataFrame
# Columns: [Employee, Age, Dept, Pay, Promoted Salary]
# Index: []

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#   Employee   Age          Dept      Pay  Promoted Salary
# 0    Alice  31.0            IT      NaN           170000
# 1     Rose  78.0       Finance      NaN           170000
# 2      Eve  96.0    Production      NaN            84000
# 3      Ali   NaN  Supply Chain  13000.0           130000
# 4     Jane  12.0           QAC  39200.0           392000
# 5    Alice  31.0            IT      NaN           120000

# %%
# invalid values
# Lambda
df['Promoted Salary'] = df['Promoted Salary'].apply(lambda x:x/10 if x > 300000 else x)

# %%
df
# Out:
#   Employee   Age          Dept      Pay  Promoted Salary
# 0    Alice  31.0            IT      NaN         170000.0
# 1     Rose  78.0       Finance      NaN         170000.0
# 2      Eve  96.0    Production      NaN          84000.0
# 3      Ali   NaN  Supply Chain  13000.0         130000.0
# 4     Jane  12.0           QAC  39200.0          39200.0
# 5    Alice  31.0            IT      NaN         120000.0

# %%
# if the employee column is having first and last name with any separator then we can split the first and last name
# df[["first_name", "last_name"]] = df["name"].str.split("_") # if underscore is the separator

# %%
def multiplying_age(x):
  return x * 2

df["Age"] = df["Age"].apply(multiplying_age)
df
# Out:
#   Employee    Age          Dept      Pay  Promoted Salary
# 0    Alice   62.0            IT      NaN         170000.0
# 1     Rose  156.0       Finance      NaN         170000.0
# 2      Eve  192.0    Production      NaN          84000.0
# 3      Ali    NaN  Supply Chain  13000.0         130000.0
# 4     Jane   24.0           QAC  39200.0          39200.0
# 5    Alice   62.0            IT      NaN         120000.0

# %%
df["Age"] = df["Age"].apply(lambda x:x/2)
df
# Out:
#   Employee   Age          Dept      Pay  Promoted Salary
# 0    Alice  15.5            IT      NaN         170000.0
# 1     Rose  39.0       Finance      NaN         170000.0
# 2      Eve  48.0    Production      NaN          84000.0
# 3      Ali   NaN  Supply Chain  13000.0         130000.0
# 4     Jane   6.0           QAC  39200.0          39200.0
# 5    Alice  15.5            IT      NaN         120000.0

# %%
# Joins -> left, right, outer, inner
# merge is similar to inner join


department_info = {
    "Dept" : ["HR", "IT", "Finance"],
    "Location" : ["New York", "San Francisco", "Chicago"],
    "Manager" : ["Laura", "Steve", "Ninaa"]
}

df1 = pd.DataFrame(department_info)
df1
# Out:
#       Dept       Location Manager
# 0       HR       New York   Laura
# 1       IT  San Francisco   Steve
# 2  Finance        Chicago   Ninaa

# %%
# Concat
pd.concat([df, df1])
# Out:
#   Employee   Age          Dept      Pay  Promoted Salary       Location  \
# 0    Alice  15.5            IT      NaN         170000.0            NaN
# 1     Rose  39.0       Finance      NaN         170000.0            NaN
# 2      Eve  48.0    Production      NaN          84000.0            NaN
# 3      Ali   NaN  Supply Chain  13000.0         130000.0            NaN
# 4     Jane   6.0           QAC  39200.0          39200.0            NaN
# 5    Alice  15.5            IT      NaN         120000.0            NaN
# 0      NaN   NaN            HR      NaN              NaN       New York
# 1      NaN   NaN            IT      NaN              NaN  San Francisco
# 2      NaN   NaN       Finance      NaN              NaN        Chicago
#
#   Manager
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 0   Laura
# 1   Steve
# 2   Ninaa

# %%
pd.concat([df, df1], axis = 1)
# Out:
#   Employee   Age          Dept      Pay  Promoted Salary     Dept  \
# 0    Alice  15.5            IT      NaN         170000.0       HR
# 1     Rose  39.0       Finance      NaN         170000.0       IT
# 2      Eve  48.0    Production      NaN          84000.0  Finance
# 3      Ali   NaN  Supply Chain  13000.0         130000.0      NaN
# 4     Jane   6.0           QAC  39200.0          39200.0      NaN
# 5    Alice  15.5            IT      NaN         120000.0      NaN
#
#         Location Manager
# 0       New York   Laura
# 1  San Francisco   Steve
# 2        Chicago   Ninaa
# 3            NaN     NaN
# 4            NaN     NaN
# 5            NaN     NaN

# %%
# If I want Dept column only once then we use merge
pd.merge(df, df1, on = "Dept")
# Out:
#   Employee   Age     Dept  Pay  Promoted Salary       Location Manager
# 0    Alice  15.5       IT  NaN         170000.0  San Francisco   Steve
# 1     Rose  39.0  Finance  NaN         170000.0        Chicago   Ninaa
# 2    Alice  15.5       IT  NaN         120000.0  San Francisco   Steve

# %%
# if you are using Anaconda or VS Code you have to wirte the whole path of csv or Excel Sheet
# if you are using Google Collab, you will have to upload the file here first and then write its name.

# data = pd.read_csv(write here)

# if your date column is in object data type, we can convert to date time format using this syntax,
# df['date'] = pd.to_datetime(df['date'])
