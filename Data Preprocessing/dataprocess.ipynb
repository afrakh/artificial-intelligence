# %%
import pandas as pd
data=pd.read_excel('titanic_modified.xlsx')
data
# Out:
#         sex   age  sibsp  parch     fare   class    who  adult_male deck  \
# 0      male  22.0      1      0   7.2500   Third    man        True  NaN
# 1    female  38.0      1      0  71.2833   First  woman       False    C
# 2    female  26.0      0      0   7.9250   Third  woman       False  NaN
# 3    female  35.0      1      0  53.1000   First  woman       False    C
# 4      male  35.0      0      0   8.0500   Third    man        True  NaN
# ..      ...   ...    ...    ...      ...     ...    ...         ...  ...
# 886    male  27.0      0      0  13.0000  Second    man        True  NaN
# 887  female  19.0      0      0  30.0000   First  woman       False    B
# 888  female   NaN      1      2  23.4500   Third  woman       False  NaN
# 889    male  26.0      0      0  30.0000   First    man        True    C
# 890    male  32.0      0      0   7.7500   Third    man        True  NaN
#
#      embark_town alive  alone
# 0    Southampton    no  False
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sex          891 non-null    object
#  1   age          714 non-null    float64
#  2   sibsp        891 non-null    int64
#  3   parch        891 non-null    int64
#  4   fare         891 non-null    float64
#  5   class        891 non-null    object
#  6   who          891 non-null    object
#  7   adult_male   891 non-null    bool
#  8   deck         203 non-null    object
#  9   embark_town  889 non-null    object
#  10  alive        891 non-null    object
#  11  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(2), object(6)
# memory usage: 71.5+ KB

# %%
data.head()
# Out:
#       sex   age  sibsp  parch     fare  class    who  adult_male deck  \
# 0    male  22.0      1      0   7.2500  Third    man        True  NaN
# 1  female  38.0      1      0  71.2833  First  woman       False    C
# 2  female  26.0      0      0   7.9250  Third  woman       False  NaN
# 3  female  35.0      1      0  53.1000  First  woman       False    C
# 4    male  35.0      0      0   8.0500  Third    man        True  NaN
#
#    embark_town alive  alone
# 0  Southampton    no  False
# 1    Cherbourg   yes  False
# 2  Southampton   yes   True
# 3  Southampton   yes  False
# 4  Southampton    no   True

# %%
data.tail()
# Out:
#         sex   age  sibsp  parch   fare   class    who  adult_male deck  \
# 886    male  27.0      0      0  13.00  Second    man        True  NaN
# 887  female  19.0      0      0  30.00   First  woman       False    B
# 888  female   NaN      1      2  23.45   Third  woman       False  NaN
# 889    male  26.0      0      0  30.00   First    man        True    C
# 890    male  32.0      0      0   7.75   Third    man        True  NaN
#
#      embark_town alive  alone
# 886  Southampton    no   True
# 887  Southampton   yes   True
# 888  Southampton    no  False
# 889    Cherbourg   yes   True
# 890   Queenstown    no   True

# %%
x = data.drop("alive", axis=1)
x
# Out:
#         sex   age  sibsp  parch     fare   class    who  adult_male deck  \
# 0      male  22.0      1      0   7.2500   Third    man        True  NaN
# 1    female  38.0      1      0  71.2833   First  woman       False    C
# 2    female  26.0      0      0   7.9250   Third  woman       False  NaN
# 3    female  35.0      1      0  53.1000   First  woman       False    C
# 4      male  35.0      0      0   8.0500   Third    man        True  NaN
# ..      ...   ...    ...    ...      ...     ...    ...         ...  ...
# 886    male  27.0      0      0  13.0000  Second    man        True  NaN
# 887  female  19.0      0      0  30.0000   First  woman       False    B
# 888  female   NaN      1      2  23.4500   Third  woman       False  NaN
# 889    male  26.0      0      0  30.0000   First    man        True    C
# 890    male  32.0      0      0   7.7500   Third    man        True  NaN
#
#      embark_town  alone
# 0    Southampton  False
# 1      Cherbourg  False
# ...

# %%
y = data["alive"]
y
# Out:
# 0       no
# 1      yes
# 2      yes
# 3      yes
# 4       no
#       ...
# 886     no
# 887    yes
# 888     no
# 889    yes
# 890     no
# Name: alive, Length: 891, dtype: object

# %%
x['sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
x['sex'] = x['sex'].replace('male', 1)
x['sex'] = x['sex'].replace('female', 0)
x
# Out:
# /tmp/ipython-input-441215277.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   x['sex'] = x['sex'].replace('female', 0)
#      sex   age  sibsp  parch     fare   class    who  adult_male deck  \
# 0      1  22.0      1      0   7.2500   Third    man        True  NaN
# 1      0  38.0      1      0  71.2833   First  woman       False    C
# 2      0  26.0      0      0   7.9250   Third  woman       False  NaN
# 3      0  35.0      1      0  53.1000   First  woman       False    C
# 4      1  35.0      0      0   8.0500   Third    man        True  NaN
# ..   ...   ...    ...    ...      ...     ...    ...         ...  ...
# 886    1  27.0      0      0  13.0000  Second    man        True  NaN
# ...

# %%
x['embark_town'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
x['embark_town'] = x['embark_town'].replace({
    'Southampton': 0,
    'Cherbourg': 1,
    'Queenstown': 2
}).astype('Int64')
x
# Out:
#      sex   age  sibsp  parch     fare   class    who  adult_male deck  \
# 0      1  22.0      1      0   7.2500   Third    man        True  NaN
# 1      0  38.0      1      0  71.2833   First  woman       False    C
# 2      0  26.0      0      0   7.9250   Third  woman       False  NaN
# 3      0  35.0      1      0  53.1000   First  woman       False    C
# 4      1  35.0      0      0   8.0500   Third    man        True  NaN
# ..   ...   ...    ...    ...      ...     ...    ...         ...  ...
# 886    1  27.0      0      0  13.0000  Second    man        True  NaN
# 887    0  19.0      0      0  30.0000   First  woman       False    B
# 888    0   NaN      1      2  23.4500   Third  woman       False  NaN
# 889    1  26.0      0      0  30.0000   First    man        True    C
# 890    1  32.0      0      0   7.7500   Third    man        True  NaN
#
#      embark_town  alone
# 0              0  False
# 1              1  False
# 2              0   True
# 3              0  False
# ...

# %%
x['class'].unique()
# Out:
# array(['Third', 'First', 'Second'], dtype=object)

# %%
x['class']=x['class'].replace('First',1)
x['class']=x['class'].replace('Second',2)
x['class']=x['class'].replace('Third',3)
x
# Out:
# /tmp/ipython-input-38491126.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   x['class']=x['class'].replace('Third',3)
#      sex   age  sibsp  parch     fare  class    who  adult_male deck  \
# 0      1  22.0      1      0   7.2500      3    man        True  NaN
# 1      0  38.0      1      0  71.2833      1  woman       False    C
# 2      0  26.0      0      0   7.9250      3  woman       False  NaN
# 3      0  35.0      1      0  53.1000      1  woman       False    C
# 4      1  35.0      0      0   8.0500      3    man        True  NaN
# ..   ...   ...    ...    ...      ...    ...    ...         ...  ...
# 886    1  27.0      0      0  13.0000      2    man        True  NaN
# 887    0  19.0      0      0  30.0000      1  woman       False    B
# ...

# %%
x['adult_male'].unique()
# Out:
# array([ True, False])

# %%
x['adult_male']= x['adult_male'].replace(True,1)
x['adult_male']= x['adult_male'].replace(False,0)
x
# Out:
# /tmp/ipython-input-121919277.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   x['adult_male']= x['adult_male'].replace(False,0)
#      sex   age  sibsp  parch     fare  class    who  adult_male deck  \
# 0      1  22.0      1      0   7.2500      3    man           1  NaN
# 1      0  38.0      1      0  71.2833      1  woman           0    C
# 2      0  26.0      0      0   7.9250      3  woman           0  NaN
# 3      0  35.0      1      0  53.1000      1  woman           0    C
# 4      1  35.0      0      0   8.0500      3    man           1  NaN
# ..   ...   ...    ...    ...      ...    ...    ...         ...  ...
# 886    1  27.0      0      0  13.0000      2    man           1  NaN
# ...

# %%
x['who'].unique()
# Out:
# array(['man', 'woman', 'child'], dtype=object)

# %%
x['who']=x['who'].replace('child',3)
x['who']=x['who'].replace('man',1)
x['who']=x['who'].replace('woman',2)
x
# Out:
# /tmp/ipython-input-2890288995.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   x['who']=x['who'].replace('woman',2)
#      sex   age  sibsp  parch     fare  class  who  adult_male deck  \
# 0      1  22.0      1      0   7.2500      3    1           1  NaN
# 1      0  38.0      1      0  71.2833      1    2           0    C
# 2      0  26.0      0      0   7.9250      3    2           0  NaN
# 3      0  35.0      1      0  53.1000      1    2           0    C
# 4      1  35.0      0      0   8.0500      3    1           1  NaN
# ..   ...   ...    ...    ...      ...    ...  ...         ...  ...
# 886    1  27.0      0      0  13.0000      2    1           1  NaN
# 887    0  19.0      0      0  30.0000      1    2           0    B
# ...

# %%
x['alone'].unique()
# Out:
# array([False,  True])

# %%
x['alone']=x['alone'].replace(True,1)
x['alone']=x['alone'].replace(False,0)
x
# Out:
# /tmp/ipython-input-1525857096.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   x['alone']=x['alone'].replace(False,0)
#      sex   age  sibsp  parch     fare  class  who  adult_male deck  \
# 0      1  22.0      1      0   7.2500      3    1           1  NaN
# 1      0  38.0      1      0  71.2833      1    2           0    C
# 2      0  26.0      0      0   7.9250      3    2           0  NaN
# 3      0  35.0      1      0  53.1000      1    2           0    C
# 4      1  35.0      0      0   8.0500      3    1           1  NaN
# ..   ...   ...    ...    ...      ...    ...  ...         ...  ...
# 886    1  27.0      0      0  13.0000      2    1           1  NaN
# 887    0  19.0      0      0  30.0000      1    2           0    B
# ...

# %%
x['deck'].unique()
# Out:
# array([nan, 'C', 'E', 'G', 'D', 'A', 'B', 'F'], dtype=object)

# %%
x['deck']=x['deck'].replace({
    'A': 1,
    'B': 2,
    'C': 3,
    'D': 4,
    'E': 5,
    'F': 6,
    'G': 7
})

x
# Out:
#      sex   age  sibsp  parch     fare  class  who  adult_male  deck  \
# 0      1  22.0      1      0   7.2500      3    1           1  <NA>
# 1      0  38.0      1      0  71.2833      1    2           0     2
# 2      0  26.0      0      0   7.9250      3    2           0  <NA>
# 3      0  35.0      1      0  53.1000      1    2           0     2
# 4      1  35.0      0      0   8.0500      3    1           1  <NA>
# ..   ...   ...    ...    ...      ...    ...  ...         ...   ...
# 886    1  27.0      0      0  13.0000      2    1           1  <NA>
# 887    0  19.0      0      0  30.0000      1    2           0     1
# 888    0  30.0      1      2  23.4500      3    2           0  <NA>
# 889    1  26.0      0      0  30.0000      1    1           1     2
# 890    1  32.0      0      0   7.7500      3    1           1  <NA>
#
#      embark_town  alone
# 0              0      0
# 1              1      0
# 2              0      1
# 3              0      0
# ...

# %%
x['age'] = x['age'].fillna(
    x.groupby('who')['age'].transform('median')
)
x
# Out:
#      sex   age  sibsp  parch     fare  class  who  adult_male  deck  \
# 0      1  22.0      1      0   7.2500      3    1           1  <NA>
# 1      0  38.0      1      0  71.2833      1    2           0     2
# 2      0  26.0      0      0   7.9250      3    2           0  <NA>
# 3      0  35.0      1      0  53.1000      1    2           0     2
# 4      1  35.0      0      0   8.0500      3    1           1  <NA>
# ..   ...   ...    ...    ...      ...    ...  ...         ...   ...
# 886    1  27.0      0      0  13.0000      2    1           1  <NA>
# 887    0  19.0      0      0  30.0000      1    2           0     1
# 888    0  30.0      1      2  23.4500      3    2           0  <NA>
# 889    1  26.0      0      0  30.0000      1    1           1     2
# 890    1  32.0      0      0   7.7500      3    1           1  <NA>
#
#      embark_town  alone
# 0              0      0
# 1              1      0
# 2              0      1
# 3              0      0
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sex          891 non-null    int64
#  1   age          891 non-null    float64
#  2   sibsp        891 non-null    int64
#  3   parch        891 non-null    int64
#  4   fare         891 non-null    float64
#  5   class        891 non-null    int64
#  6   who          891 non-null    int64
#  7   adult_male   891 non-null    int64
#  8   deck         203 non-null    Int64
#  9   embark_town  889 non-null    Int64
#  10  alone        891 non-null    int64
# dtypes: Int64(2), float64(2), int64(7)
# memory usage: 78.4 KB

# %%
x['deck']=x['deck'].fillna(0)
x
# Out:
#      sex   age  sibsp  parch     fare  class  who  adult_male  deck  \
# 0      1  22.0      1      0   7.2500      3    1           1     0
# 1      0  38.0      1      0  71.2833      1    2           0     2
# 2      0  26.0      0      0   7.9250      3    2           0     0
# 3      0  35.0      1      0  53.1000      1    2           0     2
# 4      1  35.0      0      0   8.0500      3    1           1     0
# ..   ...   ...    ...    ...      ...    ...  ...         ...   ...
# 886    1  27.0      0      0  13.0000      2    1           1     0
# 887    0  19.0      0      0  30.0000      1    2           0     1
# 888    0  30.0      1      2  23.4500      3    2           0     0
# 889    1  26.0      0      0  30.0000      1    1           1     2
# 890    1  32.0      0      0   7.7500      3    1           1     0
#
#      embark_town  alone
# 0              0      0
# 1              1      0
# 2              0      1
# 3              0      0
# ...

# %%
x.dropna(subset=['embark_town'], inplace=True)
x
# Out:
#      sex   age  sibsp  parch     fare  class  who  adult_male  deck  \
# 0      1  22.0      1      0   7.2500      3    1           1     0
# 1      0  38.0      1      0  71.2833      1    2           0     2
# 2      0  26.0      0      0   7.9250      3    2           0     0
# 3      0  35.0      1      0  53.1000      1    2           0     2
# 4      1  35.0      0      0   8.0500      3    1           1     0
# ..   ...   ...    ...    ...      ...    ...  ...         ...   ...
# 886    1  27.0      0      0  13.0000      2    1           1     0
# 887    0  19.0      0      0  30.0000      1    2           0     1
# 888    0  30.0      1      2  23.4500      3    2           0     0
# 889    1  26.0      0      0  30.0000      1    1           1     2
# 890    1  32.0      0      0   7.7500      3    1           1     0
#
#      embark_town  alone
# 0              0      0
# 1              1      0
# 2              0      1
# 3              0      0
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sex          889 non-null    int64
#  1   age          889 non-null    float64
#  2   sibsp        889 non-null    int64
#  3   parch        889 non-null    int64
#  4   fare         889 non-null    float64
#  5   class        889 non-null    int64
#  6   who          889 non-null    int64
#  7   adult_male   889 non-null    int64
#  8   deck         889 non-null    Int64
#  9   embark_town  889 non-null    Int64
#  10  alone        889 non-null    int64
# dtypes: Int64(2), float64(2), int64(7)
# memory usage: 85.1 KB

# %%
data
# Out:
#         sex   age  sibsp  parch     fare   class    who  adult_male deck  \
# 0      male  22.0      1      0   7.2500   Third    man        True  NaN
# 1    female  38.0      1      0  71.2833   First  woman       False    C
# 2    female  26.0      0      0   7.9250   Third  woman       False  NaN
# 3    female  35.0      1      0  53.1000   First  woman       False    C
# 4      male  35.0      0      0   8.0500   Third    man        True  NaN
# ..      ...   ...    ...    ...      ...     ...    ...         ...  ...
# 886    male  27.0      0      0  13.0000  Second    man        True  NaN
# 887  female  19.0      0      0  30.0000   First  woman       False    B
# 888  female   NaN      1      2  23.4500   Third  woman       False  NaN
# 889    male  26.0      0      0  30.0000   First    man        True    C
# 890    male  32.0      0      0   7.7500   Third    man        True  NaN
#
#      embark_town alive  alone
# 0    Southampton    no  False
# ...

# %%
x
# Out:
#      sex   age  sibsp  parch     fare  class  who  adult_male  deck  \
# 0      1  22.0      1      0   7.2500      3    1           1     0
# 1      0  38.0      1      0  71.2833      1    2           0     2
# 2      0  26.0      0      0   7.9250      3    2           0     0
# 3      0  35.0      1      0  53.1000      1    2           0     2
# 4      1  35.0      0      0   8.0500      3    1           1     0
# ..   ...   ...    ...    ...      ...    ...  ...         ...   ...
# 886    1  27.0      0      0  13.0000      2    1           1     0
# 887    0  19.0      0      0  30.0000      1    2           0     1
# 888    0  30.0      1      2  23.4500      3    2           0     0
# 889    1  26.0      0      0  30.0000      1    1           1     2
# 890    1  32.0      0      0   7.7500      3    1           1     0
#
#      embark_town  alone
# 0              0      0
# 1              1      0
# 2              0      1
# 3              0      0
# ...

# %%
x=x.drop(columns=['adult_male'])
x
# Out:
#      sex   age  sibsp  parch     fare  class  who  deck  embark_town  alone
# 0      1  22.0      1      0   7.2500      3    1     0            0      0
# 1      0  38.0      1      0  71.2833      1    2     2            1      0
# 2      0  26.0      0      0   7.9250      3    2     0            0      1
# 3      0  35.0      1      0  53.1000      1    2     2            0      0
# 4      1  35.0      0      0   8.0500      3    1     0            0      1
# ..   ...   ...    ...    ...      ...    ...  ...   ...          ...    ...
# 886    1  27.0      0      0  13.0000      2    1     0            0      1
# 887    0  19.0      0      0  30.0000      1    2     1            0      1
# 888    0  30.0      1      2  23.4500      3    2     0            0      0
# 889    1  26.0      0      0  30.0000      1    1     2            1      1
# 890    1  32.0      0      0   7.7500      3    1     0            2      1
#
# [889 rows x 10 columns]

# %%
bins = [0, 1, 12, 19, 40, 60, float('inf')]
labels = ['infant', 'child', 'teenager', 'young', 'middle-aged', 'old']

x['age_group'] = pd.cut(x['age'], bins=bins, labels=labels, right=True)

# %%
x.tail()
# Out:
#      sex   age  sibsp  parch   fare  class  who  deck  embark_town  alone  \
# 886    1  27.0      0      0  13.00      2    1     0            0      1
# 887    0  19.0      0      0  30.00      1    2     1            0      1
# 888    0  30.0      1      2  23.45      3    2     0            0      0
# 889    1  26.0      0      0  30.00      1    1     2            1      1
# 890    1  32.0      0      0   7.75      3    1     0            2      1
#
#     age_group
# 886     young
# 887  teenager
# 888     young
# 889     young
# 890     young

# %%
import matplotlib.pyplot as plt

plt.hist(x['age'], bins=30, edgecolor='k')
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# Note if data is skewed, use  normalization

# %%
# applying normalization

from sklearn.preprocessing import MinMaxScaler
norm = MinMaxScaler()
x[['age']]=norm.fit_transform(x[['age']])
x['age']
# Out:
# 0      0.271174
# 1      0.472229
# 2      0.321438
# 3      0.434531
# 4      0.434531
#          ...
# 886    0.334004
# 887    0.233476
# 888    0.371701
# 889    0.321438
# 890    0.396833
# Name: age, Length: 889, dtype: float64

# %%
plt.hist(x['fare'], bins = 30, edgecolor='y')
plt.title('Fare Distribuition')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.show()

# Note if data is skewed, use  normalization

# %%
# Applying Normalization

from sklearn.preprocessing import MinMaxScaler
norm = MinMaxScaler()
x[['fare']]=norm.fit_transform(x[['fare']])
x['fare']
# Out:
# 0      0.014151
# 1      0.139136
# 2      0.015469
# 3      0.103644
# 4      0.015713
#          ...
# 886    0.025374
# 887    0.058556
# 888    0.045771
# 889    0.058556
# 890    0.015127
# Name: fare, Length: 889, dtype: float64

# %%
x
# Out:
#      sex       age  sibsp  parch      fare  class  who  deck  embark_town  \
# 0      1  0.271174      1      0  0.014151      3    1     0            0
# 1      0  0.472229      1      0  0.139136      1    2     2            1
# 2      0  0.321438      0      0  0.015469      3    2     0            0
# 3      0  0.434531      1      0  0.103644      1    2     2            0
# 4      1  0.434531      0      0  0.015713      3    1     0            0
# ..   ...       ...    ...    ...       ...    ...  ...   ...          ...
# 886    1  0.334004      0      0  0.025374      2    1     0            0
# 887    0  0.233476      0      0  0.058556      1    2     1            0
# 888    0  0.371701      1      2  0.045771      3    2     0            0
# 889    1  0.321438      0      0  0.058556      1    1     2            1
# 890    1  0.396833      0      0  0.015127      3    1     0            2
#
#      alone age_group
# 0        0     young
# 1        0     young
# ...

# %%
x['who']=x['who'].replace({
    1:'man',
    2:'woman',
    3:'child'
})

# %%
x['embark_town'] = x['embark_town'].astype('object')
x['embark_town']=x['embark_town'].replace(0, 'Southampton')
x['embark_town']=x['embark_town'].replace(1, 'Cherbourg')
x['embark_town']=x['embark_town'].replace(2, 'Queenstown')
x
# Out:
#      sex       age  sibsp  parch      fare  class    who  deck  embark_town  \
# 0      1  0.271174      1      0  0.014151      3    man     0  Southampton
# 1      0  0.472229      1      0  0.139136      1  woman     2    Cherbourg
# 2      0  0.321438      0      0  0.015469      3  woman     0  Southampton
# 3      0  0.434531      1      0  0.103644      1  woman     2  Southampton
# 4      1  0.434531      0      0  0.015713      3    man     0  Southampton
# ..   ...       ...    ...    ...       ...    ...    ...   ...          ...
# 886    1  0.334004      0      0  0.025374      2    man     0  Southampton
# 887    0  0.233476      0      0  0.058556      1  woman     1  Southampton
# 888    0  0.371701      1      2  0.045771      3  woman     0  Southampton
# 889    1  0.321438      0      0  0.058556      1    man     2    Cherbourg
# 890    1  0.396833      0      0  0.015127      3    man     0   Queenstown
#
#      alone age_group
# 0        0     young
# ...

# %%
import pandas as pd
print(x.columns)
# One Hot encoding
x = pd.get_dummies(x, columns=['who', 'embark_town'], drop_first=False)
x
# Out:
# Index(['sex', 'age', 'sibsp', 'parch', 'fare', 'class', 'deck', 'alone',
#        'age_group', 'who_child', 'who_man', 'who_woman',
#        'embark_town_Cherbourg', 'embark_town_Queenstown',
#        'embark_town_Southampton'],
#       dtype='object')
#      sex       age  sibsp  parch      fare  class  deck  alone age_group  \
# 0      1  0.271174      1      0  0.014151      3     0      0     young
# 1      0  0.472229      1      0  0.139136      1     2      0     young
# 2      0  0.321438      0      0  0.015469      3     0      1     young
# 3      0  0.434531      1      0  0.103644      1     2      0     young
# 4      1  0.434531      0      0  0.015713      3     0      1     young
# ..   ...       ...    ...    ...       ...    ...   ...    ...       ...
# 886    1  0.334004      0      0  0.025374      2     0      1     young
# 887    0  0.233476      0      0  0.058556      1     1      1  teenager
# ...
